# %% [markdown]
# #SAN JOAQUIN R A JERSEY POINT CA
#
# The following stationNZ codes are going to be used:
# - NZD16
# - NZD19
# - NZD28
# - NZD086

# %%
import pandas as pd
import numpy as np
import datetime

# %%
NZlist = ['NZD16', 'NZD19', 'NZD28', 'NZD086']

# %%
df = pd.read_excel('../usgs/11337190.xlsx')
zoo_df = pd.read_excel('../zooplankton/zoo_df.xlsx')

# %%
df.drop(labels = 0,inplace = True)

# %%
zoo_df = zoo_df.loc[zoo_df.StationNZ.isin(NZlist)]

# %%
zoo_df
# Out:
#       Unnamed: 0 SampleDate StationNZ Region  TotalLimno  ALLCYCADULTS  \
# 2          20224 2010-01-06     NZD16    SJR         427           427
# 5          20227 2010-01-07     NZD19  SoDel          80            80
# 6          20228 2010-01-07     NZD28  SoDel         107           107
# 20         20242 2010-02-04     NZD19  SoDel           0             0
# 21         20243 2010-02-04     NZD28  SoDel           0             0
# ...          ...        ...       ...    ...         ...           ...
# 2182       22404 2019-10-03     NZD28  SoDel         213           213
# 2185       22407 2019-10-04     NZD16    SJR           0             0
# 2200       22422 2019-11-04     NZD28  SoDel           0             0
# 2204       22426 2019-11-05     NZD16    SJR           0             0
# 2217       22439 2019-12-03     NZD28  SoDel         133           374
#
#       ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS
# 2           107        4056         4056
# 5            53        3255         3149
# 6           213        8646         3469
# 20          107        6618         8646
# 21          106        6956         8815
# ...         ...         ...          ...
# 2182        213       14089         5444
# 2185          0        6404         2135
# 2200        160       13769         5123
# 2204          0        5764         2562
# 2217        240        9339         2909
#
# [325 rows x 9 columns]

# %%
zoo_df.SampleDate
# Out:
# 2      2010-01-06
# 5      2010-01-07
# 6      2010-01-07
# 20     2010-02-04
# 21     2010-02-04
#           ...
# 2182   2019-10-03
# 2185   2019-10-04
# 2200   2019-11-04
# 2204   2019-11-05
# 2217   2019-12-03
# Name: SampleDate, Length: 325, dtype: datetime64[ns]

# %%
df.datetime
# Out:
# 1         2017-10-08 00:00:00
# 2         2017-10-08 00:15:00
# 3         2017-10-08 00:30:00
# 4         2017-10-08 00:45:00
# 5         2017-10-08 01:00:00
#                  ...
# 105080    2020-10-07 18:30:00
# 105081    2020-10-07 18:45:00
# 105082    2020-10-07 19:00:00
# 105083    2020-10-07 19:15:00
# 105084    2020-10-07 19:30:00
# Name: datetime, Length: 105084, dtype: object

# %%
zoo_df.SampleDate = pd.to_datetime(zoo_df.SampleDate)
df.datetime = pd.to_datetime(df.datetime)

# %%
from gauss import gauss_dist
dist = gauss_dist(11)
dist
# Out:
# [0.008812229292562286,
#  0.02714357714347937,
#  0.06511405659938267,
#  0.12164907301380959,
#  0.17699835683135567,
#  0.20056541423882082,
#  0.17699835683135567,
#  0.12164907301380959,
#  0.06511405659938267,
#  0.02714357714347937,
#  0.008812229292562286]

# %%
df.columns
# Out:
# Index(['datetime', '164023_00010', '164024_00095', '164025_00400',
#        '164026_00300', '164028_63680', '164034_99133', '248715_32316',
#        '248718_32295', '257814_00480', '260064_00301'],
#       dtype='object')

# %%
df.columns = ['datetime', 'temp_c', 'specific_conductance', 'ph',
       'dissolved_o2_mg_l', 'turbidity', 'nitrate_nitrite', 'fChl',
       'organic_matter', 'salinity', 'dissolved_o2_percent_sat']

# %%
df['11_day_temp_c'] = np.nan
df['11_day_specific_conductance'] = np.nan
df['11_day_ph'] = np.nan
df['11_day_dissolved_o2_mg_l'] = np.nan
df['11_day_turbidity'] = np.nan
df['11_day_nitrate_nitrite'] = np.nan
df['11_day_organic_matter'] = np.nan
df['11_day_salinity'] = np.nan
df['11_day_dissolved_o2_percent_sat'] = np.nan

# %%
df = df.loc[df.datetime >= (zoo_df.SampleDate.min() - datetime.timedelta(days = 12))]

for i in range(11,len(df)):
    df.loc[i,'11_day_temp_c'] = sum(np.multiply(dist,list(df.temp_c[i-11:i])))
    df.loc[i,'11_day_specific_conductance'] = sum(np.multiply(dist,list(df.specific_conductance[i-11:i])))
    df.loc[i,'11_day_ph'] = sum(np.multiply(dist,list(df.ph[i-11:i])))
    df.loc[i,'11_day_dissolved_o2_mg_l'] = sum(np.multiply(dist,list(df.dissolved_o2_mg_l[i-11:i])))
    df.loc[i,'11_day_turbidity'] = sum(np.multiply(dist,list(df.turbidity[i-11:i])))
    df.loc[i,'11_day_nitrate_nitrite'] = sum(np.multiply(dist,list(df.nitrate_nitrite[i-11:i])))
    df.loc[i,'11_day_organic_matter'] = sum(np.multiply(dist,list(df.organic_matter[i-11:i])))
    df.loc[i,'11_day_salinity'] = sum(np.multiply(dist,list(df.salinity[i-11:i])))
    df.loc[i,'11_day_dissolved_o2_percent_sat'] = sum(np.multiply(dist,list(df.dissolved_o2_percent_sat[i-11:i])))

df = df[11:]

# %%
df
# Out:
#                   datetime temp_c specific_conductance   ph dissolved_o2_mg_l  \
# 12     2017-10-08 02:45:00   18.8                  172  7.8                 9
# 13     2017-10-08 03:00:00   18.8                  174  7.8                 9
# 14     2017-10-08 03:15:00   18.8                  175  7.8               8.9
# 15     2017-10-08 03:30:00   18.8                  175  7.8               8.9
# 16     2017-10-08 03:45:00   18.8                  179  7.8                 9
# ...                    ...    ...                  ...  ...               ...
# 105080 2020-10-07 18:30:00   21.6                 3230  8.2               8.4
# 105081 2020-10-07 18:45:00   21.6                 3280  8.2               8.3
# 105082 2020-10-07 19:00:00   21.6                 3430  8.2               8.4
# 105083 2020-10-07 19:15:00   21.6                 3460  8.2               8.3
# 105084 2020-10-07 19:30:00   21.6                 3540  8.2               8.3
#
#        turbidity nitrate_nitrite fChl organic_matter salinity  \
# 12           4.7             0.3  NaN           13.7      0.1
# 13           4.3             0.3  NaN           13.6      0.1
# 14           5.2             0.3  NaN           13.6      0.1
# 15           5.3             0.3  NaN           13.4      0.1
# 16           5.1             0.3  NaN           13.4      0.1
# ...          ...             ...  ...            ...      ...
# 105080       4.4            0.32  2.5           22.7      1.7
# 105081       4.1            0.32  2.7           22.9      1.7
# 105082       4.2            0.32  2.5           22.9      1.8
# 105083       4.6            0.33  2.6           22.9      1.8
# 105084       4.2            0.32  2.9             23      1.8
#
#        dissolved_o2_percent_sat  11_day_temp_c  11_day_specific_conductance  \
# 12                           96      18.939091                   175.662393
# 13                           96      18.918676                   177.716127
# 14                           96      18.900000                   178.112048
# 15                           96      18.881324                   177.036172
# 16                           96      18.860909                   175.526890
# ...                         ...            ...                          ...
# 105080                       96      21.760028                  2654.814239
# 105081                       96      21.736376                  2808.140651
# 105082                       96      21.712165                  2941.187913
# 105083                       96      21.687835                  3051.540892
# 105084                       96            NaN                          NaN
#
#         11_day_ph  11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 12       7.856433                  9.060028          3.506113
# 13       7.839091                  9.039972          3.657542
# 14       7.822272                  9.021391          3.817286
# 15       7.810107                  9.006511          3.981409
# 16       7.803596                  8.994370          4.164259
# ...           ...                       ...               ...
# 105080   8.169254                  8.403596          4.443303
# 105081   8.181324                  8.400000          4.419105
# 105082   8.190774                  8.397286          4.395727
# 105083   8.196404                  8.392607          4.369635
# 105084        NaN                       NaN               NaN
#
#         11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 12                    0.288842              14.027528         0.100000
# 13                    0.292144              14.042870         0.100000
# 14                    0.294329              14.011337         0.100000
# 15                    0.295419              13.935716         0.100000
# 16                    0.296156              13.838125         0.100000
# ...                        ...                    ...              ...
# 105080                0.318881              22.158848         1.375014
# 105081                0.318266              22.321339         1.460228
# 105082                0.318318              22.463643         1.531446
# 105083                0.318872              22.579963         1.588131
# 105084                     NaN                    NaN              NaN
#
#         11_day_dissolved_o2_percent_sat
# 12                            97.414472
# 13                            97.163196
# 14                            96.944651
# 15                            96.756702
# 16                            96.571124
# ...                                 ...
# 105080                        96.804425
# 105081                        96.609095
# 105082                        96.399717
# 105083                        96.222719
# 105084                              NaN
#
# [105073 rows x 20 columns]

# %%
zoo_df = zoo_df.merge(df, how='left', left_on='SampleDate', right_on='datetime')
zoo_df
# Out:
#      Unnamed: 0 SampleDate StationNZ Region  TotalLimno  ALLCYCADULTS  \
# 0         20224 2010-01-06     NZD16    SJR         427           427
# 1         20227 2010-01-07     NZD19  SoDel          80            80
# 2         20228 2010-01-07     NZD28  SoDel         107           107
# 3         20242 2010-02-04     NZD19  SoDel           0             0
# 4         20243 2010-02-04     NZD28  SoDel           0             0
# ..          ...        ...       ...    ...         ...           ...
# 320       22404 2019-10-03     NZD28  SoDel         213           213
# 321       22407 2019-10-04     NZD16    SJR           0             0
# 322       22422 2019-11-04     NZD28  SoDel           0             0
# 323       22426 2019-11-05     NZD16    SJR           0             0
# 324       22439 2019-12-03     NZD28  SoDel         133           374
#
#      ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS   datetime  ...  \
# 0          107        4056         4056        NaT  ...
# 1           53        3255         3149        NaT  ...
# 2          213        8646         3469        NaT  ...
# 3          107        6618         8646        NaT  ...
# 4          106        6956         8815        NaT  ...
# ..         ...         ...          ...        ...  ...
# 320        213       14089         5444 2019-10-03  ...
# 321          0        6404         2135 2019-10-04  ...
# 322        160       13769         5123 2019-11-04  ...
# 323          0        5764         2562 2019-11-05  ...
# 324        240        9339         2909 2019-12-03  ...
#
#     dissolved_o2_percent_sat 11_day_temp_c 11_day_specific_conductance  \
# 0                        NaN           NaN                         NaN
# 1                        NaN           NaN                         NaN
# 2                        NaN           NaN                         NaN
# 3                        NaN           NaN                         NaN
# 4                        NaN           NaN                         NaN
# ..                       ...           ...                         ...
# 320                       94     19.249197                  200.248567
# 321                       95     19.184240                  231.007556
# 322                       92     14.972193                  163.268834
# 323                       93     15.000000                  165.361176
# 324                       95     10.929865                 1412.406808
#
#     11_day_ph 11_day_dissolved_o2_mg_l 11_day_turbidity  \
# 0         NaN                      NaN              NaN
# 1         NaN                      NaN              NaN
# 2         NaN                      NaN              NaN
# 3         NaN                      NaN              NaN
# 4         NaN                      NaN              NaN
# ..        ...                      ...              ...
# 320  7.860028                 8.780442         4.710096
# 321  7.810107                 8.802714         5.256678
# 322  7.522272                 9.300000         4.148551
# 323  7.581419                 9.384240         3.744515
# 324  7.639972                10.499119        30.215193
#
#     11_day_nitrate_nitrite 11_day_organic_matter 11_day_salinity  \
# 0                      NaN                   NaN             NaN
# 1                      NaN                   NaN             NaN
# 2                      NaN                   NaN             NaN
# 3                      NaN                   NaN             NaN
# 4                      NaN                   NaN             NaN
# ..                     ...                   ...             ...
# 320                    NaN             20.089491        0.100000
# 321                    NaN             20.006405        0.100000
# 322                    NaN             20.395046        0.100000
# 323                    NaN             20.439570        0.100000
# 324                    NaN             20.928011        0.680039
#
#     11_day_dissolved_o2_percent_sat
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 320                       95.000000
# 321                       95.399717
# 322                       92.390905
# 323                       92.991188
# 324                       95.600283
#
# [325 rows x 29 columns]

# %%
zoo_df = zoo_df.loc[zoo_df.SampleDate >= datetime.datetime(2017,10,10)]

# %%
len(zoo_df)
# Out:
# 51

# %%
zoo_df.columns
# Out:
# Index(['Unnamed: 0', 'SampleDate', 'StationNZ', 'Region', 'TotalLimno',
#        'ALLCYCADULTS', 'ALLCYCJUV', 'ALLCOPNAUP', 'ALLROTIFERS', 'datetime',
#        'temp_c', 'specific_conductance', 'ph', 'dissolved_o2_mg_l',
#        'turbidity', 'nitrate_nitrite', 'fChl', 'organic_matter', 'salinity',
#        'dissolved_o2_percent_sat', '11_day_temp_c',
#        '11_day_specific_conductance', '11_day_ph', '11_day_dissolved_o2_mg_l',
#        '11_day_turbidity', '11_day_nitrate_nitrite', '11_day_organic_matter',
#        '11_day_salinity', '11_day_dissolved_o2_percent_sat'],
#       dtype='object')

# %%
zoo_df.drop(columns=['Unnamed: 0', 'SampleDate', 'StationNZ', 'Region', 'datetime'], inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
zoo_df
# Out:
#      TotalLimno  ALLCYCADULTS  ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS temp_c  \
# 274         320           320        427       23482         9393   17.9
# 275         187           187        934       16624         4483   17.9
# 276         107           107        107        8432         5123   15.5
# 277         427           427        107        5337         2775   15.6
# 278         445           445        356        7027         5070   11.3
# 279         534           534        400       16010         1734   11.1
# 280         107           107       1067        6084        11848    9.9
# 281         427           427        534        7365         7472     10
# 282           0             0          0        6084         4269     12
# 283          80            80          0        3505         2788     12
# 284           0             0          0        1681         2482   12.2
# 285           0             0        427       20493         8859   12.6
# 286           0             0        111        6118         6451   13.1
# 287           0             0          0       18412         1734   16.2
# 288           0             0        107        8646        10140     16
# 289           0             0        160       25190         3469    NaN
# 290           0             0        213       28605         5977    NaN
# 291         211           211        211       13948         5600   21.8
# 292           0             0          0       19319         2135   21.7
# 293           0             0        107       10674         3309   22.4
# 294         213           213        320       26684         8752   22.7
# 295         427           427       1174      117303         6831   22.6
# 296         854           854       2562       29779         3949   22.4
# 297         534           534       1601       30100         6404   20.5
# 298        6724          6724       5123       55396         2455   20.2
# 299        1494          1494       2135       40773         5017   18.1
# 300        5844          5844       4403       68284         1281   17.9
# 301         213           213        640        8219         3522   11.4
# 302         534           534       1067       11101          961   11.4
# 303         213           213        320        5764         2775    9.3
# 304         107           107        534        8112         7472    9.6
# 305           0             0        107       10353        22308   10.1
# 306           0             0        213        5977         4376   11.5
# 307           0             0        213        8646        18679   11.6
# 308           0             0        213       25937         2348   15.3
# 309           0             0        427        6938        21134     15
# 310           0             0        107       16224         3309   18.1
# 311           0             0        213       35116         5444   18.8
# 312           0             0        470       24891         5009     21
# 313           0             0        107       14409         9606     21
# 314           0             0        667       22281         6938   22.8
# 315           0             0          0       12141        13876   22.8
# 316         400           400        400       21080        10273   24.1
# 317        1334          1334       2402       30953         3336     24
# 318           0             0        160       15930         7445   23.3
# 319           0             0        640       10033         4483   23.3
# 320         213           213        213       14089         5444   19.1
# 321           0             0          0        6404         2135     19
# 322           0             0        160       13769         5123   14.9
# 323           0             0          0        5764         2562     15
# 324         133           374        240        9339         2909   10.8
#
#     specific_conductance   ph dissolved_o2_mg_l turbidity  ...  \
# 274                  172  7.8               9.2       4.9  ...
# 275                  198  7.8               9.2       6.2  ...
# 276                  271  7.6               9.2       3.5  ...
# 277                  258  7.6               9.2       3.6  ...
# 278                 1280  7.6               9.9       6.8  ...
# 279                 1060  7.6                10         6  ...
# 280                  949  7.5              10.3       5.7  ...
# 281                 1340  7.5              10.3       6.3  ...
# 282                  325  7.6               9.7       5.4  ...
# 283                  325  7.6               9.7       5.4  ...
# 284                  326  7.6               9.8       4.9  ...
# 285                  293  7.8              10.4       6.1  ...
# 286                  293  7.8              10.4       6.9  ...
# 287                  182  7.7               9.2       6.3  ...
# 288                  170  7.6               9.3       6.5  ...
# 289                  NaN  NaN               NaN       4.3  ...
# 290                  NaN  NaN               NaN       4.7  ...
# 291                  213  7.9               8.4       3.7  ...
# 292                  223    8               8.6       4.8  ...
# 293                  539  7.9               8.4       7.3  ...
# 294                  812    8               8.4       7.5  ...
# 295                  668    8               8.4         6  ...
# 296                  901    8               8.4       6.5  ...
# 297                 1180  8.1               8.5       3.7  ...
# 298                 1800  8.1               8.6       5.6  ...
# 299                 1350  7.8               8.8       4.3  ...
# 300                 1560  7.8               8.9       4.8  ...
# 301                 1190  7.6               9.4       4.5  ...
# 302                 1180  7.6               9.5       3.9  ...
# 303                  806  7.7              10.2      14.7  ...
# 304                  602  7.6               9.9      10.6  ...
# 305                  235  7.6              10.2        20  ...
# 306                  160  7.5                10      14.8  ...
# 307                  185  7.6              10.2      13.9  ...
# 308                  169  7.6               9.8       5.6  ...
# 309                  174  7.7               9.8       5.7  ...
# 310                  149  7.8               9.3         5  ...
# 311                  154  7.9               9.4       5.4  ...
# 312                  128  7.6               8.4       5.1  ...
# 313                  128  7.6               8.4       5.1  ...
# 314                  157  7.6               8.2       5.5  ...
# 315                  178  7.6               8.2         6  ...
# 316                  549  7.6               7.8       6.6  ...
# 317                  748  7.7                 8       7.6  ...
# 318                  222  7.9               7.8       4.7  ...
# 319                  262  7.9               7.9       5.1  ...
# 320                  177  7.8               8.7       3.8  ...
# 321                  191  7.8               8.8       4.5  ...
# 322                  156  7.5               9.3       5.8  ...
# 323                  157  7.5               9.4       4.2  ...
# 324                  758  7.6              10.4      37.4  ...
#
#     dissolved_o2_percent_sat 11_day_temp_c 11_day_specific_conductance  \
# 274                       96     17.970135                  195.824577
# 275                       97     18.012165                  255.112062
# 276                       92     15.577728                  252.405926
# 277                       92     15.600000                  233.002626
# 278                       91     11.300000                 1210.804276
# 279                       91     11.139972                  908.192523
# 280                       91      9.900000                 1251.803537
# 281                       91     10.000000                 1395.210570
# 282                       90     12.003596                  339.517713
# 283                       90     12.003596                  339.517713
# 284                       92     12.200000                  332.269172
# 285                       98     12.741352                  296.328182
# 286                       99     13.180085                  293.859892
# 287                       94     16.212165                  180.933925
# 288                       94     15.999119                  173.374466
# 289                      NaN           NaN                         NaN
# 290                      NaN           NaN                         NaN
# 291                       96     21.800881                  221.538064
# 292                       97     21.777728                  213.837011
# 293                       97     22.537257                  401.003540
# 294                       98     22.743567                  806.360041
# 295                       97     22.483539                  807.769135
# 296                       97     22.500000                  818.891945
# 297                       95     20.599119                 1488.312970
# 298                       95     20.200000                 1917.334251
# 299                       94     18.311284                 1849.895231
# 300                       94     17.977728                 2192.406183
# 301                       86     11.439972                 1393.073952
# 302                       87     11.403596                         NaN
# 303                       89      9.200000                  797.656597
# 304                       87      9.600000                         NaN
# 305                       91     10.177728                  238.228543
# 306                       92     11.650374                  168.542890
# 307                       94     11.590774                  181.523317
# 308                       97     15.396404                  178.575100
# 309                       97     15.099119                  175.834666
# 310                       98     18.276847                  151.064378
# 311                      101     18.803596                  152.961323
# 312                       95     21.176847                  128.313402
# 313                       95     21.176847                  128.313402
# 314                       95     22.822272                  161.517941
# 315                       96     22.860028                  170.617480
# 316                       93     24.082300                  690.218781
# 317                       95     24.000881                  771.780756
# 318                       92     23.377728                  267.797772
# 319                       93     23.336376                         NaN
# 320                       94     19.249197                  200.248567
# 321                       95     19.184240                  231.007556
# 322                       92     14.972193                  163.268834
# 323                       93     15.000000                  165.361176
# 324                       95     10.929865                 1412.406808
#
#     11_day_ph 11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 274  7.800000                 9.149921          6.683658
# 275  7.740853                 9.025867          9.532130
# 276  7.600881                 9.199048          3.811088
# 277  7.609226                 9.239091          3.404589
# 278  7.600000                 9.900881          7.061364
# 279  7.633460                10.060028          5.632662
# 280  7.503596                10.300000          6.616320
# 281  7.567621                10.289893          5.638638
# 282  7.585121                 9.760028          4.848553
# 283  7.585121                 9.760028          4.848553
# 284  7.600000                 9.899119          4.420833
# 285  7.800000                10.419558          5.516237
# 286  7.800881                10.390774          5.756245
# 287  7.700000                 9.203596          7.036243
# 288  7.600000                 9.300000          7.977937
# 289       NaN                      NaN          4.303178
# 290       NaN                      NaN          4.694005
# 291  7.900000                 8.334342          4.334575
# 292  7.993489                 8.657314          4.307172
# 293  7.907393                 8.400881          5.767154
# 294  8.000000                 8.416618          5.806195
# 295  8.000000                 8.429865          6.388285
# 296  7.958553                 8.274088          4.941892
# 297  8.109226                 8.543663          5.456833
# 298  8.100000                 8.677728          5.210820
# 299  7.800000                 8.796404          5.908092
# 300  7.803596                 8.832379          5.638315
# 301  7.600000                 9.362244          4.691467
# 302  7.600000                 9.427807          5.087975
# 303  7.700000                10.210107         16.647864
# 304  7.699119                 9.875670         10.118199
# 305  7.619558                10.197286         26.498157
# 306  7.579062                10.000000         13.682418
# 307  7.622272                10.200000         15.148497
# 308  7.660028                 9.800000          5.528450
# 309  7.700000                 9.722272          6.284957
# 310  7.837756                 9.300000          4.993974
# 311  7.839972                 9.400000          5.877785
# 312  7.610107                 8.439972          5.090045
# 313  7.610107                 8.439972          5.090045
# 314  7.600000                 8.183181          5.372879
# 315  7.622272                 8.287835          6.243859
# 316  7.613023                 7.905630          6.698687
# 317  7.687835                 8.000000          5.995473
# 318  7.900000                 7.959147          5.651402
# 319  7.900000                 7.995523          5.328681
# 320  7.860028                 8.780442          4.710096
# 321  7.810107                 8.802714          5.256678
# 322  7.522272                 9.300000          4.148551
# 323  7.581419                 9.384240          3.744515
# 324  7.639972                10.499119         30.215193
#
#      11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 274                0.301011              13.714064         0.100000
# 275                0.308989              14.078749         0.100000
# 276                0.498989              17.332461         0.100000
# 277                0.508989              18.017114         0.100000
# 278                0.638989              27.145784         0.589893
# 279                0.630000              27.915700         0.422272
# 280                0.611011              27.164666         0.611284
# 281                0.621216              27.489830         0.677728
# 282                0.759349              54.492279         0.139972
# 283                0.759349              54.492279         0.139972
# 284                0.752006              55.052657         0.100000
# 285                0.702315              65.126756         0.100000
# 286                0.706294              65.404584         0.100000
# 287                0.472315              48.282072         0.100000
# 288                0.440000              47.162814         0.100000
# 289                     NaN                    NaN              NaN
# 290                     NaN                    NaN              NaN
# 291                0.420000              27.958825         0.100000
# 292                     NaN              26.626565         0.100000
# 293                0.300000              21.254626         0.189893
# 294                0.269640              20.929849         0.396404
# 295                0.173997              20.247053         0.396404
# 296                0.181011              20.346050         0.389893
# 297                0.227014              20.363877         0.727807
# 298                0.241216              20.540267         0.962086
# 299                     NaN              19.754077         0.913703
# 300                     NaN              19.965360         1.111889
# 301                0.765731              37.975108         0.687835
# 302                0.776654              38.869772              NaN
# 303                0.879075              52.757311         0.400000
# 304                0.882411              56.655763              NaN
# 305                0.974636              83.781925         0.100000
# 306                0.689238              55.716357         0.100000
# 307                0.715422              57.581931         0.100000
# 308                0.460563              34.844064         0.100000
# 309                0.450000              34.389814         0.100000
# 310                0.358024              22.218404         0.100000
# 311                0.357685              23.241258         0.100000
# 312                0.360000              22.544160         0.100000
# 313                0.360000              22.544160         0.100000
# 314                0.320000              20.682214         0.100000
# 315                0.321770              20.328500         0.100000
# 316                0.310827              20.754338         0.300000
# 317                0.318142              20.823606         0.379786
# 318                0.335865              20.462748         0.100000
# 319                0.339729              20.595319              NaN
# 320                     NaN              20.089491         0.100000
# 321                     NaN              20.006405         0.100000
# 322                     NaN              20.395046         0.100000
# 323                     NaN              20.439570         0.100000
# 324                     NaN              20.928011         0.680039
#
#      11_day_dissolved_o2_percent_sat
# 274                        96.555515
# 275                        95.258675
# 276                        92.432097
# 277                        92.817766
# 278                        91.000000
# 279                        91.786093
# 280                        91.777281
# 281                        91.000000
# 282                        90.972856
# 283                        90.972856
# 284                        92.000000
# 285                        98.399717
# 286                        98.972856
# 287                        93.795858
# 288                        94.186763
# 289                              NaN
# 290                              NaN
# 291                        94.831814
# 292                        98.656585
# 293                        97.372574
# 294                        98.101070
# 295                        97.539698
# 296                        95.740885
# 297                        95.409482
# 298                        96.286259
# 299                        94.000000
# 300                        94.035956
# 301                        86.000000
# 302                        87.000000
# 303                        89.000000
# 304                        86.756702
# 305                        90.600283
# 306                        92.000000
# 307                        94.000000
# 308                        97.964044
# 309                        97.000000
# 310                        98.668973
# 311                       101.000000
# 312                        95.008812
# 313                        95.008812
# 314                        95.371512
# 315                        96.231531
# 316                        94.056302
# 317                        95.000000
# 318                        93.591470
# 319                        93.564327
# 320                        95.000000
# 321                        95.399717
# 322                        92.390905
# 323                        92.991188
# 324                        95.600283
#
# [51 rows x 24 columns]

# %%
zoo_df.to_excel('../merged/1137190.xlsx')
