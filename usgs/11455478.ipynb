# %% [markdown]
# # SACRAMENTO R A DECKER ISLAND NR RIO VISTA CA
#
# The following stationNZ codes are going to be used:
# - NZ064

# %%
import pandas as pd
import numpy as np
import datetime

# %%
NZlist = ['NZ064']

# %%
df = pd.read_excel('../usgs/11455478.xlsx')
zoo_df = pd.read_excel('../zooplankton/zoo_df.xlsx')

# %%
df.drop(labels = 0,inplace = True)

# %%
zoo_df = zoo_df.loc[zoo_df.StationNZ.isin(NZlist)]

# %%
zoo_df
# Out:
#       Unnamed: 0 SampleDate StationNZ Region  TotalLimno  ALLCYCADULTS  \
# 7          20229 2010-01-08     NZ064   SacR         854           854
# 26         20248 2010-02-08     NZ064   SacR           0             0
# 49         20271 2010-03-10     NZ064   SacR           0             0
# 70         20292 2010-04-07     NZ064   SacR          80            80
# 87         20309 2010-05-07     NZ064   SacR           0             0
# ...          ...        ...       ...    ...         ...           ...
# 2129       22351 2019-07-08     NZ064   SacR         106           106
# 2154       22376 2019-08-08     NZ064   SacR         747           747
# 2174       22396 2019-09-06     NZ064   SacR         160           160
# 2190       22412 2019-10-07     NZ064   SacR         320           320
# 2209       22431 2019-11-06     NZ064   SacR         427           427
#
#       ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS
# 7           160        7258         3896
# 26         1281       27805        28605
# 49           53        4803         8432
# 70           80        1561         1321
# 87            0        3522         2455
# ...         ...         ...          ...
# 2129        106        9877         2974
# 2154        560        9153         1868
# 2174        213        6778         1494
# 2190        107        6084          694
# 2209        320       29459         1067
#
# [116 rows x 9 columns]

# %%
zoo_df.SampleDate
# Out:
# 7      2010-01-08
# 26     2010-02-08
# 49     2010-03-10
# 70     2010-04-07
# 87     2010-05-07
#           ...
# 2129   2019-07-08
# 2154   2019-08-08
# 2174   2019-09-06
# 2190   2019-10-07
# 2209   2019-11-06
# Name: SampleDate, Length: 116, dtype: datetime64[ns]

# %%
df.datetime
# Out:
# 1         2017-10-08 00:00:00
# 2         2017-10-08 00:15:00
# 3         2017-10-08 00:30:00
# 4         2017-10-08 00:45:00
# 5         2017-10-08 01:00:00
#                  ...
# 106703    2020-10-07 18:45:00
# 106704    2020-10-07 19:00:00
# 106705    2020-10-07 19:15:00
# 106706    2020-10-07 19:30:00
# 106707    2020-10-07 19:45:00
# Name: datetime, Length: 106707, dtype: object

# %%
zoo_df.SampleDate = pd.to_datetime(zoo_df.SampleDate)
df.datetime = pd.to_datetime(df.datetime)

# %%
from gauss import gauss_dist
dist = gauss_dist(11)
dist
# Out:
# [0.008812229292562286,
#  0.02714357714347937,
#  0.06511405659938267,
#  0.12164907301380959,
#  0.17699835683135567,
#  0.20056541423882082,
#  0.17699835683135567,
#  0.12164907301380959,
#  0.06511405659938267,
#  0.02714357714347937,
#  0.008812229292562286]

# %%
df.columns
# Out:
# Index(['datetime', '16214_00010', '16215_00095', '16216_00400', '16218_63680',
#        '16220_00300', '16221_99133', '248800_32316', '248804_32295',
#        '257815_00480', '260066_00301'],
#       dtype='object')

# %%
df.columns = ['datetime', 'temp_c', 'specific_conductance', 'ph', 'turbidity',
           'dissolved_o2_mg_l', 'nitrate_nitrite', 'fChl', 'organic_matter',
              'salinity', 'dissolved_o2_percent_sat']

# %%
df['11_day_temp_c'] = np.nan
df['11_day_specific_conductance'] = np.nan
df['11_day_ph'] = np.nan
df['11_day_dissolved_o2_mg_l'] = np.nan
df['11_day_turbidity'] = np.nan
df['11_day_nitrate_nitrite'] = np.nan
df['11_day_organic_matter'] = np.nan
df['11_day_salinity'] = np.nan
df['11_day_dissolved_o2_percent_sat'] = np.nan

# %%
df.tail()
# Out:
#                   datetime temp_c specific_conductance   ph turbidity  \
# 106703 2020-10-07 18:45:00   21.2                 5320  7.9      10.5
# 106704 2020-10-07 19:00:00   21.2                 5490  7.9       9.1
# 106705 2020-10-07 19:15:00   21.2                 5560  7.9       7.5
# 106706 2020-10-07 19:30:00   21.2                 5650    8       6.4
# 106707 2020-10-07 19:45:00   21.2                 5440    8       6.9
#
#        dissolved_o2_mg_l nitrate_nitrite fChl organic_matter salinity  \
# 106703                 8            0.34    2           22.7      2.8
# 106704                 8            0.34  1.9           22.9      2.9
# 106705                 8            0.33    2           22.5        3
# 106706                 8            0.34    2           22.7        3
# 106707                 8             NaN  NaN           22.6      2.9
#
#        dissolved_o2_percent_sat  11_day_temp_c  11_day_specific_conductance  \
# 106703                       91            NaN                          NaN
# 106704                       91            NaN                          NaN
# 106705                       92            NaN                          NaN
# 106706                       92            NaN                          NaN
# 106707                       92            NaN                          NaN
#
#         11_day_ph  11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 106703        NaN                       NaN               NaN
# 106704        NaN                       NaN               NaN
# 106705        NaN                       NaN               NaN
# 106706        NaN                       NaN               NaN
# 106707        NaN                       NaN               NaN
#
#         11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 106703                     NaN                    NaN              NaN
# 106704                     NaN                    NaN              NaN
# 106705                     NaN                    NaN              NaN
# 106706                     NaN                    NaN              NaN
# 106707                     NaN                    NaN              NaN
#
#         11_day_dissolved_o2_percent_sat
# 106703                              NaN
# 106704                              NaN
# 106705                              NaN
# 106706                              NaN
# 106707                              NaN

# %%
df = df.loc[df.datetime >= (zoo_df.SampleDate.min() - datetime.timedelta(days = 12))]
df = df.loc[df.datetime < datetime.datetime(2020,1,1)]

for i in range(11,len(df)):
    df.loc[i,'11_day_temp_c'] = sum(np.multiply(dist,list(df.temp_c[i-11:i])))
    df.loc[i,'11_day_specific_conductance'] = sum(np.multiply(dist,list(df.specific_conductance[i-11:i])))
    df.loc[i,'11_day_ph'] = sum(np.multiply(dist,list(df.ph[i-11:i])))
    df.loc[i,'11_day_dissolved_o2_mg_l'] = sum(np.multiply(dist,list(df.dissolved_o2_mg_l[i-11:i])))
    df.loc[i,'11_day_turbidity'] = sum(np.multiply(dist,list(df.turbidity[i-11:i])))
    df.loc[i,'11_day_nitrate_nitrite'] = sum(np.multiply(dist,list(df.nitrate_nitrite[i-11:i])))
    df.loc[i,'11_day_organic_matter'] = sum(np.multiply(dist,list(df.organic_matter[i-11:i])))
    df.loc[i,'11_day_salinity'] = sum(np.multiply(dist,list(df.salinity[i-11:i])))
    df.loc[i,'11_day_dissolved_o2_percent_sat'] = sum(np.multiply(dist,list(df.dissolved_o2_percent_sat[i-11:i])))

df = df[11:]

# %%
df
# Out:
#                  datetime temp_c specific_conductance   ph turbidity  \
# 12    2017-10-08 02:45:00   17.3                  114  7.4       6.4
# 13    2017-10-08 03:00:00   17.3                  114  7.4       7.3
# 14    2017-10-08 03:15:00   17.3                  114  7.4       7.2
# 15    2017-10-08 03:30:00   17.3                  113  7.4       8.4
# 16    2017-10-08 03:45:00   17.4                  113  7.4         8
# ...                   ...    ...                  ...  ...       ...
# 79743 2019-12-31 22:45:00    9.2                  201  7.4       7.8
# 79744 2019-12-31 23:00:00    9.2                  201  7.4       7.8
# 79745 2019-12-31 23:15:00    9.1                  201  7.4       7.5
# 79746 2019-12-31 23:30:00    9.1                  201  7.4       7.5
# 79747 2019-12-31 23:45:00    9.1                  202  7.4       7.4
#
#       dissolved_o2_mg_l nitrate_nitrite fChl organic_matter salinity  \
# 12                  8.8             NaN  NaN              4        0
# 13                  8.7             NaN  NaN              4        0
# 14                  8.7             NaN  NaN            3.9        0
# 15                  8.7             NaN  NaN            3.7        0
# 16                  8.7             NaN  NaN            3.6        0
# ...                 ...             ...  ...            ...      ...
# 79743              10.2            0.59  1.7           34.1      0.1
# 79744              10.2            0.59  1.7             34      0.1
# 79745              10.2            0.59  1.7           34.1      0.1
# 79746              10.2            0.58  1.7           33.9      0.1
# 79747              10.2            0.58  1.7           33.9      0.1
#
#       dissolved_o2_percent_sat  11_day_temp_c  11_day_specific_conductance  \
# 12                          91      17.200881                   113.991188
# 13                          91      17.203596                   114.000000
# 14                          91      17.210107                   114.000000
# 15                          91      17.222272                   113.991188
# 16                          91      17.240853                   113.964044
# ...                        ...            ...                          ...
# 79743                       89       9.239972                   202.432718
# 79744                       89       9.222272                   201.903725
# 79745                       89       9.209226                   201.518412
# 79746                       89       9.200000                   201.258675
# 79747                       89            NaN                          NaN
#
#        11_day_ph  11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 12      7.403596                  8.797286          5.568698
# 13      7.400881                  8.792607          5.648747
# 14      7.400000                  8.784240          5.822867
# 15      7.400000                  8.772193          6.087668
# 16      7.400000                  8.757672          6.412446
# ...          ...                       ...               ...
# 79743   7.410988                 10.189893          6.917179
# 79744   7.397965                 10.196404          7.148121
# 79745   7.388716                 10.199119          7.341129
# 79746   7.382300                 10.200000          7.479183
# 79747        NaN                       NaN               NaN
#
#        11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 12                        NaN               4.076921              0.0
# 13                        NaN               4.014360              0.0
# 14                        NaN               3.975840              0.0
# 15                        NaN               3.960768              0.0
# 16                        NaN               3.955194              0.0
# ...                       ...                    ...              ...
# 79743                0.607685              34.098238              0.1
# 79744                0.605643              34.087930              0.1
# 79745                0.602986              34.079943              0.1
# 79746                0.599912              34.074908              0.1
# 79747                     NaN                    NaN              NaN
#
#        11_day_dissolved_o2_percent_sat
# 12                           91.000000
# 13                           91.000000
# 14                           91.000000
# 15                           91.000000
# 16                           91.000000
# ...                                ...
# 79743                        88.101070
# 79744                        88.222719
# 79745                        88.399717
# 79746                        88.600283
# 79747                              NaN
#
# [79736 rows x 20 columns]

# %%
zoo_df = zoo_df.merge(df, how='left', left_on='SampleDate', right_on='datetime')
zoo_df
# Out:
#      Unnamed: 0 SampleDate StationNZ Region  TotalLimno  ALLCYCADULTS  \
# 0         20229 2010-01-08     NZ064   SacR         854           854
# 1         20248 2010-02-08     NZ064   SacR           0             0
# 2         20271 2010-03-10     NZ064   SacR           0             0
# 3         20292 2010-04-07     NZ064   SacR          80            80
# 4         20309 2010-05-07     NZ064   SacR           0             0
# ..          ...        ...       ...    ...         ...           ...
# 111       22351 2019-07-08     NZ064   SacR         106           106
# 112       22376 2019-08-08     NZ064   SacR         747           747
# 113       22396 2019-09-06     NZ064   SacR         160           160
# 114       22412 2019-10-07     NZ064   SacR         320           320
# 115       22431 2019-11-06     NZ064   SacR         427           427
#
#      ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS   datetime  ...  \
# 0          160        7258         3896        NaT  ...
# 1         1281       27805        28605        NaT  ...
# 2           53        4803         8432        NaT  ...
# 3           80        1561         1321        NaT  ...
# 4            0        3522         2455        NaT  ...
# ..         ...         ...          ...        ...  ...
# 111        106        9877         2974 2019-07-08  ...
# 112        560        9153         1868 2019-08-08  ...
# 113        213        6778         1494 2019-09-06  ...
# 114        107        6084          694 2019-10-07  ...
# 115        320       29459         1067 2019-11-06  ...
#
#     dissolved_o2_percent_sat 11_day_temp_c 11_day_specific_conductance  \
# 0                        NaN           NaN                         NaN
# 1                        NaN           NaN                         NaN
# 2                        NaN           NaN                         NaN
# 3                        NaN           NaN                         NaN
# 4                        NaN           NaN                         NaN
# ..                       ...           ...                         ...
# 111                       94     22.000881                  125.341608
# 112                       93     23.060028                  615.608820
# 113                       91     22.210988                  150.850657
# 114                       94     17.600000                  135.226736
# 115                       87     14.209226                  140.485411
#
#     11_day_ph 11_day_dissolved_o2_mg_l 11_day_turbidity  \
# 0         NaN                      NaN              NaN
# 1         NaN                      NaN              NaN
# 2         NaN                      NaN              NaN
# 3         NaN                      NaN              NaN
# 4         NaN                      NaN              NaN
# ..        ...                      ...              ...
# 111  7.503415                 8.376847        10.136107
# 112  7.700000                 8.000000        13.381606
# 113  7.504572                 7.900000         8.974993
# 114  7.654014                 8.883539         3.473161
# 115  7.472193                 8.933460         5.996744
#
#     11_day_nitrate_nitrite 11_day_organic_matter 11_day_salinity  \
# 0                      NaN                   NaN             NaN
# 1                      NaN                   NaN             NaN
# 2                      NaN                   NaN             NaN
# 3                      NaN                   NaN             NaN
# 4                      NaN                   NaN             NaN
# ..                     ...                   ...             ...
# 111               0.317773             17.140186        0.100000
# 112               0.300000             19.251885        0.289012
# 113               0.283909             19.421092        0.100000
# 114               0.300000             17.592607        0.100000
# 115               0.453638             16.094028        0.100000
#
#     11_day_dissolved_o2_percent_sat
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 111                       95.768469
# 112                       93.000000
# 113                       90.109882
# 114                       93.380324
# 115                       87.027144
#
# [116 rows x 29 columns]

# %%
zoo_df = zoo_df.loc[zoo_df.SampleDate >= datetime.datetime(2017,10,10)]

# %%
len(zoo_df)
# Out:
# 24

# %%
zoo_df.columns
# Out:
# Index(['Unnamed: 0', 'SampleDate', 'StationNZ', 'Region', 'TotalLimno',
#        'ALLCYCADULTS', 'ALLCYCJUV', 'ALLCOPNAUP', 'ALLROTIFERS', 'datetime',
#        'temp_c', 'specific_conductance', 'ph', 'turbidity',
#        'dissolved_o2_mg_l', 'nitrate_nitrite', 'fChl', 'organic_matter',
#        'salinity', 'dissolved_o2_percent_sat', '11_day_temp_c',
#        '11_day_specific_conductance', '11_day_ph', '11_day_dissolved_o2_mg_l',
#        '11_day_turbidity', '11_day_nitrate_nitrite', '11_day_organic_matter',
#        '11_day_salinity', '11_day_dissolved_o2_percent_sat'],
#       dtype='object')

# %%
zoo_df.drop(columns=['Unnamed: 0', 'SampleDate', 'StationNZ', 'Region', 'datetime'], inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
zoo_df
# Out:
#      TotalLimno  ALLCYCADULTS  ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS temp_c  \
# 92         2348          2348       1921       28392         4590   10.7
# 93         1067          1067        712       12808        12275    9.5
# 94            0             0        213        3095         5123   11.4
# 95            0             0        240        5444        17692   10.9
# 96            0             0        320        9446        21934   15.3
# 97            0             0        213       19106         3843   18.7
# 98          240           240          0       12088         1681     21
# 99        18786         18786       7365      117410          854   22.4
# 100        1708          1708       1067       14303          747   22.5
# 101       13342         13342       8432       92647          747   20.8
# 102       70490         70490      33800      318430         2001   18.7
# 103       39706         39706      15157      248482         2348     13
# 104        4483          4483       1067       30953         2989     11
# 105           0             0        427       11954        25296    8.9
# 106           0             0          0         584         1446    9.1
# 107           0             0          0       17718        43975   11.6
# 108           0             0          0       11634       142600   15.5
# 109           0             0        854       20066        54435   16.5
# 110           0           133        400       11874        61907   19.1
# 111         106           106        106        9877         2974     22
# 112         747           747        560        9153         1868     23
# 113         160           160        213        6778         1494   22.3
# 114         320           320        107        6084          694   17.6
# 115         427           427        320       29459         1067   14.3
#
#     specific_conductance   ph turbidity dissolved_o2_mg_l  ...  \
# 92                   171  7.5      12.8               9.8  ...
# 93                   185  7.5       7.7              10.2  ...
# 94                   199  7.5       8.6               9.9  ...
# 95                   197  7.6      11.2                10  ...
# 96                   137  7.3       9.9               9.3  ...
# 97                   174  7.8      11.8               9.1  ...
# 98                   160  7.6         8               8.5  ...
# 99                   336  7.8      19.4               8.3  ...
# 100                  164  7.7         9                 8  ...
# 101                  207  7.8       9.5                 8  ...
# 102                  299  7.7      13.6               8.4  ...
# 103                 4850  7.7      16.5               9.3  ...
# 104                  284  7.5       6.8               8.9  ...
# 105                  218  7.7      17.4              10.6  ...
# 106                  204  7.5      28.3                10  ...
# 107                  187  7.5      72.4               9.4  ...
# 108                  199  7.5      16.2               9.6  ...
# 109                  131  7.4       6.9               9.4  ...
# 110                  105  7.3       6.9                 9  ...
# 111                  123  7.3      12.4               8.3  ...
# 112                  402  7.7      11.4                 8  ...
# 113                  142  7.5       9.7               7.9  ...
# 114                  135  7.3       3.3                 9  ...
# 115                  142  7.5       6.3               8.9  ...
#
#     dissolved_o2_percent_sat 11_day_temp_c 11_day_specific_conductance  \
# 92                        88     10.850079                  185.544876
# 93                        90      9.574133                  270.317263
# 94                        91     11.310107                  195.591470
# 95                        91     10.936376                  196.842395
# 96                        93     15.243567                  133.582464
# 97                        98     18.886954                  173.823002
# 98                        95     21.022272                  165.962665
# 99                        95     22.126749                  737.439519
# 100                       92     22.240471                  308.119202
# 101                       90     20.789012                  264.900492
# 102                       90     18.737756                  507.365098
# 103                       90     12.613152                 2361.442111
# 104                       81     11.023153                  293.913988
# 105                       91      8.827902                  217.806265
# 106                       87      9.154076                  201.526090
# 107                       86     11.423153                  182.380920
# 108                       96     15.472623                  187.865010
# 109                       97     16.500881                  127.478439
# 110                       97     19.032579                  105.298647
# 111                       94     22.000881                  125.341608
# 112                       93     23.060028                  615.608820
# 113                       91     22.210988                  150.850657
# 114                       94     17.600000                  135.226736
# 115                       87     14.209226                  140.485411
#
#     11_day_ph 11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 92   7.500881                 9.707393         14.871175
# 93   7.500000                10.200000          9.668872
# 94   7.500000                 9.899119          9.015286
# 95   7.600000                10.000000         10.964694
# 96   7.328783                 9.360028          7.415247
# 97   7.722272                 9.021391         11.878116
# 98   7.689893                 8.470135          9.554045
# 99   7.899119                 8.396404         17.021635
# 100  7.818676                 8.117700         13.143296
# 101  7.900000                 8.157314         11.500517
# 102  7.789893                 8.500000         20.770888
# 103  7.660028                 9.399119          7.386256
# 104  7.500000                 8.889893          9.346001
# 105  7.680667                10.600000         16.571376
# 106  7.500000                10.003596         29.501838
# 107  7.500000                 9.377728         68.197023
# 108  7.509226                 9.593489         16.039624
# 109  7.403596                 9.477728          6.550649
# 110  7.289893                 8.913703          7.549710
# 111  7.503415                 8.376847         10.136107
# 112  7.700000                 8.000000         13.381606
# 113  7.504572                 7.900000          8.974993
# 114  7.654014                 8.883539          3.473161
# 115  7.472193                 8.933460          5.996744
#
#      11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 92                 0.400360              18.873389         0.100881
# 93                 0.328230               9.943969         0.110107
# 94                 0.387014              21.924942         0.100000
# 95                 0.416496              22.025753         0.100000
# 96                 0.280000              21.516443         0.100000
# 97                 0.336003              20.595542         0.100000
# 98                 0.399552              17.699540         0.100000
# 99                 0.380671               7.129622         0.356433
# 100                0.309912              17.445724         0.139972
# 101                0.306003              20.128209         0.100881
# 102                0.400000              16.897035         0.226749
# 103                0.586003              19.836424         1.192553
# 104                0.742062              49.585872         0.100881
# 105                0.557255              36.318869         0.100000
# 106                0.493997              51.239040         0.100000
# 107                0.330000              35.248828         0.100000
# 108                0.199708              23.379036         0.100000
# 109                0.221011              14.861721         0.100000
# 110                0.190000              15.916779         0.000000
# 111                0.317773              17.140186         0.100000
# 112                0.300000              19.251885         0.289012
# 113                0.283909              19.421092         0.100000
# 114                0.300000              17.592607         0.100000
# 115                0.453638              16.094028         0.100000
#
#      11_day_dissolved_o2_percent_sat
# 92                         88.008812
# 93                         89.101070
# 94                         90.600283
# 95                         91.000000
# 96                         93.000000
# 97                         97.027144
# 98                         95.000000
# 99                         96.512554
# 100                        93.591470
# 101                        90.934886
# 102                        91.399717
# 103                        89.008812
# 104                        80.734321
# 105                        91.000000
# 106                        87.000000
# 107                        85.777281
# 108                        95.934886
# 109                        97.000000
# 110                        96.128213
# 111                        95.768469
# 112                        93.000000
# 113                        90.109882
# 114                        93.380324
# 115                        87.027144
#
# [24 rows x 24 columns]

# %%
zoo_df.to_excel('../merged/11455478.xlsx')
