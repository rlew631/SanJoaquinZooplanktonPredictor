# %% [markdown]
# # SUISUN BAY A VAN SICKLE ISLAND NR PITTSBURG CA
#
# The following stationNZ codes are going to be used:
# - NZ048
# - NZ054
# - NZ060
# - NZ074

# %%
import pandas as pd
import numpy as np
import datetime

# %%
NZlist = ['NZ048','NZ054','NZ060','NZ074']

# %%
df = pd.read_excel('../usgs/11455508.xlsx')
zoo_df = pd.read_excel('../zooplankton/zoo_df.xlsx')

# %%
df.drop(labels = 0, inplace = True)

# %%
zoo_df = zoo_df.loc[zoo_df.StationNZ.isin(NZlist)]

# %%
zoo_df
# Out:
#       Unnamed: 0 SampleDate StationNZ   Region  TotalLimno  ALLCYCADULTS  \
# 4          20226 2010-01-07     NZ074      SJR         747           747
# 8          20230 2010-01-08     NZ060  WestDel        1841          1841
# 9          20231 2010-01-08     NZ048   SuiBay        1274          1274
# 10         20232 2010-01-08     NZ054   SuiBay        7792          7792
# 19         20241 2010-02-04     NZ074      SJR           0           160
# ...          ...        ...       ...      ...         ...           ...
# 2211       22433 2019-11-06     NZ060  WestDel       37464         37464
# 2218       22440 2019-12-03     NZ074      SJR       16544         16544
# 2221       22443 2019-12-05     NZ060  WestDel       26044         26044
# 2224       22446 2019-12-06     NZ054   SuiBay       33515         33515
# 2225       22447 2019-12-06     NZ048   SuiBay       29246         29246
#
#       ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS
# 4           320        6618          961
# 8           520        8526         1241
# 9          2071        7646         2867
# 10         2348       12168         2028
# 19          320       12968        21134
# ...         ...         ...          ...
# 2211       9926      152579          320
# 2218       4056       79839          534
# 2221       6404       90406          427
# 2224       5977       96916          320
# 2225       6938       78985          213
#
# [473 rows x 9 columns]

# %%
zoo_df.SampleDate
# Out:
# 4      2010-01-07
# 8      2010-01-08
# 9      2010-01-08
# 10     2010-01-08
# 19     2010-02-04
#           ...
# 2211   2019-11-06
# 2218   2019-12-03
# 2221   2019-12-05
# 2224   2019-12-06
# 2225   2019-12-06
# Name: SampleDate, Length: 473, dtype: datetime64[ns]

# %%
df.datetime
# Out:
# 1         2017-10-08 00:00:00
# 2         2017-10-08 00:15:00
# 3         2017-10-08 00:30:00
# 4         2017-10-08 00:45:00
# 5         2017-10-08 01:00:00
#                  ...
# 104899    2020-10-07 18:45:00
# 104900    2020-10-07 19:00:00
# 104901    2020-10-07 19:15:00
# 104902    2020-10-07 19:30:00
# 104903    2020-10-07 19:45:00
# Name: datetime, Length: 104903, dtype: object

# %%
zoo_df.SampleDate = pd.to_datetime(zoo_df.SampleDate)
df.datetime = pd.to_datetime(df.datetime)

# %%
from gauss import gauss_dist
dist = gauss_dist(11)
dist
# Out:
# [0.008812229292562286,
#  0.02714357714347937,
#  0.06511405659938267,
#  0.12164907301380959,
#  0.17699835683135567,
#  0.20056541423882082,
#  0.17699835683135567,
#  0.12164907301380959,
#  0.06511405659938267,
#  0.02714357714347937,
#  0.008812229292562286]

# %%
df.columns
# Out:
# Index(['site_no', 'datetime', '164313_00010', '164314_00095', '164316_00300',
#        '164318_63680', '164324_99133', '236039_00400', '248807_32316',
#        '248810_32295', '257809_00480', '260065_00301'],
#       dtype='object')

# %%
df.drop(columns = ['site_no'], inplace = True)

# %%
df.columns = ['datetime', 'temp_c', 'specific_conductance', 'dissolved_o2_mg_l',
            'turbidity', 'nitrate_nitrite', 'ph', 'fChl',
              'organic_matter', 'salinity', 'dissolved_o2_percent_sat']

# %%
df['11_day_temp_c'] = np.nan
df['11_day_specific_conductance'] = np.nan
df['11_day_ph'] = np.nan
df['11_day_dissolved_o2_mg_l'] = np.nan
df['11_day_turbidity'] = np.nan
df['11_day_nitrate_nitrite'] = np.nan
df['11_day_organic_matter'] = np.nan
df['11_day_salinity'] = np.nan
df['11_day_dissolved_o2_percent_sat'] = np.nan

# %%
df.tail()
# Out:
#                   datetime temp_c specific_conductance dissolved_o2_mg_l  \
# 104899 2020-10-07 18:45:00   20.6                16600               8.2
# 104900 2020-10-07 19:00:00   20.6                16500               8.2
# 104901 2020-10-07 19:15:00   20.5                16400               8.2
# 104902 2020-10-07 19:30:00   20.5                16400               8.2
# 104903 2020-10-07 19:45:00   20.6                16400               8.2
#
#        turbidity nitrate_nitrite   ph fChl organic_matter salinity  \
# 104899      12.8            0.54  7.8  1.9           23.9      9.8
# 104900      11.9            0.54  7.8  1.9             24      9.7
# 104901      10.3            0.54  7.8  1.9             24      9.6
# 104902       9.7            0.54  7.9  1.9           24.1      9.6
# 104903       8.3            0.54  7.8    2           23.6      9.6
#
#        dissolved_o2_percent_sat  11_day_temp_c  11_day_specific_conductance  \
# 104899                       96            NaN                          NaN
# 104900                       96            NaN                          NaN
# 104901                       96            NaN                          NaN
# 104902                       96            NaN                          NaN
# 104903                       96            NaN                          NaN
#
#         11_day_ph  11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 104899        NaN                       NaN               NaN
# 104900        NaN                       NaN               NaN
# 104901        NaN                       NaN               NaN
# 104902        NaN                       NaN               NaN
# 104903        NaN                       NaN               NaN
#
#         11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 104899                     NaN                    NaN              NaN
# 104900                     NaN                    NaN              NaN
# 104901                     NaN                    NaN              NaN
# 104902                     NaN                    NaN              NaN
# 104903                     NaN                    NaN              NaN
#
#         11_day_dissolved_o2_percent_sat
# 104899                              NaN
# 104900                              NaN
# 104901                              NaN
# 104902                              NaN
# 104903                              NaN

# %%
df = df.loc[df.datetime >= (zoo_df.SampleDate.min() - datetime.timedelta(days = 12))]
df = df.loc[df.datetime < datetime.datetime(2020,1,1)]

for i in range(11,len(df)):
    df.loc[i,'11_day_temp_c'] = sum(np.multiply(dist,list(df.temp_c[i-11:i])))
    df.loc[i,'11_day_specific_conductance'] = sum(np.multiply(dist,list(df.specific_conductance[i-11:i])))
    df.loc[i,'11_day_ph'] = sum(np.multiply(dist,list(df.ph[i-11:i])))
    df.loc[i,'11_day_dissolved_o2_mg_l'] = sum(np.multiply(dist,list(df.dissolved_o2_mg_l[i-11:i])))
    df.loc[i,'11_day_turbidity'] = sum(np.multiply(dist,list(df.turbidity[i-11:i])))
    df.loc[i,'11_day_nitrate_nitrite'] = sum(np.multiply(dist,list(df.nitrate_nitrite[i-11:i])))
    df.loc[i,'11_day_organic_matter'] = sum(np.multiply(dist,list(df.organic_matter[i-11:i])))
    df.loc[i,'11_day_salinity'] = sum(np.multiply(dist,list(df.salinity[i-11:i])))
    df.loc[i,'11_day_dissolved_o2_percent_sat'] = sum(np.multiply(dist,list(df.dissolved_o2_percent_sat[i-11:i])))

df = df[11:]

# %%
df
# Out:
#                  datetime temp_c specific_conductance dissolved_o2_mg_l  \
# 12    2017-10-08 02:45:00   18.6                 1940               8.5
# 13    2017-10-08 03:00:00   18.6                 2230               8.5
# 14    2017-10-08 03:15:00   18.7                 2720               8.5
# 15    2017-10-08 03:30:00   18.6                 3120               8.5
# 16    2017-10-08 03:45:00   18.6                 3110               8.5
# ...                   ...    ...                  ...               ...
# 78091 2019-12-31 22:45:00    9.8                 2620               9.9
# 78092 2019-12-31 23:00:00    9.9                 2500               9.9
# 78093 2019-12-31 23:15:00    9.8                 2200               9.9
# 78094 2019-12-31 23:30:00    9.8                 2090               9.9
# 78095 2019-12-31 23:45:00    9.8                 1980               9.9
#
#       turbidity nitrate_nitrite   ph fChl organic_matter salinity  \
# 12         40.2             0.3  7.5  2.3            7.2        1
# 13         29.7             0.3  7.6  2.2            7.7      1.1
# 14         30.5            0.32  7.6  2.1            8.1      1.4
# 15           34            0.32  7.6    2            7.6      1.6
# 16           33            0.32  7.6  2.1            7.8      1.6
# ...         ...             ...  ...  ...            ...      ...
# 78091      24.3            0.84  7.6  0.6           40.3      1.3
# 78092      21.9            0.84  7.6  0.6           40.7      1.3
# 78093      20.3            0.84  7.6  0.7           40.6      1.1
# 78094      18.2            0.84  7.6  0.6           40.7        1
# 78095      17.5            0.84  7.6  0.6           40.8        1
#
#       dissolved_o2_percent_sat  11_day_temp_c  11_day_specific_conductance  \
# 12                          92      18.432379                  1033.955090
# 13                          92      18.462244                  1174.590139
# 14                          92      18.500881                  1346.473941
# 15                          92      18.540471                  1545.941220
# 16                          92      18.574133                  1774.309805
# ...                        ...            ...                          ...
# 78091                       88       9.933460                  3624.582894
# 78092                       88       9.907393                  3444.896329
# 78093                       88       9.885015                  3211.742103
# 78094                       88       9.867779                  2983.336469
# 78095                       88            NaN                          NaN
#
#        11_day_ph  11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 12      7.500000                  8.577728         15.559300
# 13      7.500881                  8.560028         17.583255
# 14      7.503596                  8.539972         20.722002
# 15      7.510107                  8.522272         24.587154
# 16      7.522272                  8.510107         28.285689
# ...          ...                       ...               ...
# 78091   7.600000                  9.900000         11.524654
# 78092   7.600000                  9.900000         12.558915
# 78093   7.600000                  9.900000         14.257992
# 78094   7.600000                  9.900000         16.454175
# 78095        NaN                       NaN               NaN
#
#        11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 12                   0.274445               7.185642         0.509930
# 13                   0.279437               7.293590         0.575851
# 14                   0.284603               7.370096         0.658675
# 15                   0.289620               7.409737         0.759032
# 16                   0.294648               7.442997         0.878661
# ...                       ...                    ...              ...
# 78091                0.848989              42.209360         1.900066
# 78092                0.847773              41.984046         1.804757
# 78093                0.846003              41.660714         1.676535
# 78094                0.843997              41.298412         1.547008
# 78095                     NaN                    NaN              NaN
#
#        11_day_dissolved_o2_percent_sat
# 12                           91.456252
# 13                           91.543748
# 14                           91.627426
# 15                           91.707177
# 16                           91.787046
# ...                                ...
# 78091                        88.600283
# 78092                        88.399717
# 78093                        88.222719
# 78094                        88.101070
# 78095                              NaN
#
# [78084 rows x 20 columns]

# %%
zoo_df = zoo_df.merge(df, how='left', left_on='SampleDate', right_on='datetime')
zoo_df
# Out:
#      Unnamed: 0 SampleDate StationNZ   Region  TotalLimno  ALLCYCADULTS  \
# 0         20226 2010-01-07     NZ074      SJR         747           747
# 1         20230 2010-01-08     NZ060  WestDel        1841          1841
# 2         20231 2010-01-08     NZ048   SuiBay        1274          1274
# 3         20232 2010-01-08     NZ054   SuiBay        7792          7792
# 4         20241 2010-02-04     NZ074      SJR           0           160
# ..          ...        ...       ...      ...         ...           ...
# 468       22433 2019-11-06     NZ060  WestDel       37464         37464
# 469       22440 2019-12-03     NZ074      SJR       16544         16544
# 470       22443 2019-12-05     NZ060  WestDel       26044         26044
# 471       22446 2019-12-06     NZ054   SuiBay       33515         33515
# 472       22447 2019-12-06     NZ048   SuiBay       29246         29246
#
#      ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS   datetime  ...  \
# 0          320        6618          961        NaT  ...
# 1          520        8526         1241        NaT  ...
# 2         2071        7646         2867        NaT  ...
# 3         2348       12168         2028        NaT  ...
# 4          320       12968        21134        NaT  ...
# ..         ...         ...          ...        ...  ...
# 468       9926      152579          320 2019-11-06  ...
# 469       4056       79839          534 2019-12-03  ...
# 470       6404       90406          427 2019-12-05  ...
# 471       5977       96916          320 2019-12-06  ...
# 472       6938       78985          213 2019-12-06  ...
#
#     dissolved_o2_percent_sat 11_day_temp_c 11_day_specific_conductance  \
# 0                        NaN           NaN                         NaN
# 1                        NaN           NaN                         NaN
# 2                        NaN           NaN                         NaN
# 3                        NaN           NaN                         NaN
# 4                        NaN           NaN                         NaN
# ..                       ...           ...                         ...
# 468                       89     14.870135                 5605.551491
# 469                       93     11.297286                10008.529080
# 470                       92     11.296404                 8496.646854
# 471                       91     11.233460                 7742.672063
# 472                       91     11.233460                 7742.672063
#
#     11_day_ph 11_day_dissolved_o2_mg_l 11_day_turbidity  \
# 0         NaN                      NaN              NaN
# 1         NaN                      NaN              NaN
# 2         NaN                      NaN              NaN
# 3         NaN                      NaN              NaN
# 4         NaN                      NaN              NaN
# ..        ...                      ...              ...
# 468       7.5                 8.781324         9.317203
# 469       7.6                 9.838032        13.425932
# 470       7.5                 9.698919         8.132004
# 471       7.5                 9.635698        10.771283
# 472       7.5                 9.635698        10.771283
#
#     11_day_nitrate_nitrite 11_day_organic_matter 11_day_salinity  \
# 0                      NaN                   NaN             NaN
# 1                      NaN                   NaN             NaN
# 2                      NaN                   NaN             NaN
# 3                      NaN                   NaN             NaN
# 4                      NaN                   NaN             NaN
# ..                     ...                   ...             ...
# 468               0.555573             21.905383        3.024795
# 469               0.684920             26.174861        5.627341
# 470               0.682421             26.777048        4.701019
# 471               0.678230             27.356940        4.261027
# 472               0.678230             27.356940        4.261027
#
#     11_day_dissolved_o2_percent_sat
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 468                       88.813237
# 469                       93.008812
# 470                       91.436626
# 471                       90.514589
# 472                       90.514589
#
# [473 rows x 29 columns]

# %%
zoo_df = zoo_df.loc[zoo_df.SampleDate >= datetime.datetime(2017,10,10)]

# %%
len(zoo_df)
# Out:
# 104

# %%
zoo_df.columns
# Out:
# Index(['Unnamed: 0', 'SampleDate', 'StationNZ', 'Region', 'TotalLimno',
#        'ALLCYCADULTS', 'ALLCYCJUV', 'ALLCOPNAUP', 'ALLROTIFERS', 'datetime',
#        'temp_c', 'specific_conductance', 'dissolved_o2_mg_l', 'turbidity',
#        'nitrate_nitrite', 'ph', 'fChl', 'organic_matter', 'salinity',
#        'dissolved_o2_percent_sat', '11_day_temp_c',
#        '11_day_specific_conductance', '11_day_ph', '11_day_dissolved_o2_mg_l',
#        '11_day_turbidity', '11_day_nitrate_nitrite', '11_day_organic_matter',
#        '11_day_salinity', '11_day_dissolved_o2_percent_sat'],
#       dtype='object')

# %%
zoo_df.drop(columns=['Unnamed: 0', 'SampleDate', 'StationNZ', 'Region', 'datetime'], inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
zoo_df
# Out:
#      TotalLimno  ALLCYCADULTS  ALLCYCJUV  ALLCOPNAUP  ALLROTIFERS temp_c  \
# 369        7792          7792       3202       91686         3736   17.8
# 370       45530         45530      33388      319175        25216   17.7
# 371       63375         63375      33355      366016        15121   17.7
# 372        1174          1174        747       23909         2455   15.3
# 373       42054         42054      22628      197675            0   15.3
# ..          ...           ...        ...         ...          ...    ...
# 468       37464         37464       9926      152579          320   14.9
# 469       16544         16544       4056       79839          534   11.2
# 470       26044         26044       6404       90406          427   11.2
# 471       33515         33515       5977       96916          320   11.3
# 472       29246         29246       6938       78985          213   11.3
#
#     specific_conductance dissolved_o2_mg_l turbidity nitrate_nitrite  ...  \
# 369                 1590               8.8      40.6             0.3  ...
# 370                 3360               8.7      40.5            0.33  ...
# 371                 3360               8.7      40.5            0.33  ...
# 372                 6880               8.9      11.4            0.49  ...
# 373                 5140               8.9        22            0.48  ...
# ..                   ...               ...       ...             ...  ...
# 468                 6230               8.8        10            0.56  ...
# 469                 6790                10      18.7            0.69  ...
# 470                 7450               9.8       7.6            0.68  ...
# 471                 9460               9.6      10.1            0.68  ...
# 472                 9460               9.6      10.1            0.68  ...
#
#     dissolved_o2_percent_sat 11_day_temp_c 11_day_specific_conductance  \
# 369                       93     17.912165                 2492.397662
# 370                       92     17.789074                 5210.122369
# 371                       92     17.789074                 5210.122369
# 372                       91     15.283539                 6624.975496
# 373                       90     15.379561                 3206.873050
# ..                       ...           ...                         ...
# 468                       89     14.870135                 5605.551491
# 469                       93     11.297286                10008.529080
# 470                       92     11.296404                 8496.646854
# 471                       91     11.233460                 7742.672063
# 472                       91     11.233460                 7742.672063
#
#     11_day_ph 11_day_dissolved_o2_mg_l  11_day_turbidity  \
# 369  7.660028                 8.800000         46.040043
# 370  7.672193                 8.672193         18.955548
# 371  7.672193                 8.672193         18.955548
# 372  7.600000                 8.940471         12.227507
# 373  7.542328                 8.900000         14.578831
# ..        ...                      ...               ...
# 468  7.500000                 8.781324          9.317203
# 469  7.600000                 9.838032         13.425932
# 470  7.500000                 9.698919          8.132004
# 471  7.500000                 9.635698         10.771283
# 472  7.500000                 9.635698         10.771283
#
#      11_day_nitrate_nitrite  11_day_organic_matter  11_day_salinity  \
# 369                0.313997               6.524374         1.272551
# 370                0.363468               9.349926         2.770032
# 371                0.363468               9.349926         2.770032
# 372                0.488836               9.363263         3.601334
# 373                0.460088               8.872018         1.659615
# ..                      ...                    ...              ...
# 468                0.555573              21.905383         3.024795
# 469                0.684920              26.174861         5.627341
# 470                0.682421              26.777048         4.701019
# 471                0.678230              27.356940         4.261027
# 472                0.678230              27.356940         4.261027
#
#      11_day_dissolved_o2_percent_sat
# 369                        93.576716
# 370                        92.757888
# 371                        92.757888
# 372                        90.926074
# 373                        89.898930
# ..                               ...
# 468                        88.813237
# 469                        93.008812
# 470                        91.436626
# 471                        90.514589
# 472                        90.514589
#
# [104 rows x 24 columns]

# %%
zoo_df.to_excel('../merged/11455508.xlsx')
